# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../../short_masivas.csv')

# %%
ogle_test = df.loc[(df['ogle_type'].notna())&(df['vsx_split']=='no_used')]

# %%
ogle_test.groupby('ogle_type').count()
# Out:
#            source_id_1  ra_1_1  dec_1_1  skiff_type  vsx_type  B2_cut_label  \
# ogle_type
# ELL                 31      31       31           9         1             6
# Mira                 9       9        9           4         2             1
# cep                519     519      519          12        25            11
# dsct               407     407      407           5        24             2
# ecl                438     438      438         196        19           105
# lpv                198     198      198          27       108             8
# rrlyr             1085    1085     1085           3        13             1
#
#            B2_cut_split  predict_B2_cut  B2_cut_probability  vsx_per  ...  \
# ogle_type                                                             ...
# ELL                  31              31                  31        0  ...
# Mira                  9               9                   9        0  ...
# ...

# %%
ogle_test.loc[(ogle_test['multiplicity_probability']>0.4)].groupby('ogle_type').count()
# Out:
#            source_id_1  ra_1_1  dec_1_1  skiff_type  vsx_type  B2_cut_label  \
# ogle_type
# ELL                 30      30       30           9         0             6
# cep                 10      10       10           1         0             1
# dsct                76      76       76           4        10             2
# ecl                418     418      418         195         5           104
# lpv                 41      41       41          14         4             4
# rrlyr               42      42       42           1         0             1
#
#            B2_cut_split  predict_B2_cut  B2_cut_probability  vsx_per  ...  \
# ogle_type                                                             ...
# ELL                  30              30                  30        0  ...
# cep                  10              10                  10        0  ...
# dsct                 76              76                  76        0  ...
# ...

# %%
ogle_test.loc[(ogle_test['multiplicity_probability']>0.4)].groupby('ogle_type').count() / ogle_test.groupby('ogle_type').count()
# Out:
#            source_id_1    ra_1_1   dec_1_1  skiff_type  vsx_type  \
# ogle_type
# ELL           0.967742  0.967742  0.967742    1.000000  0.000000
# Mira               NaN       NaN       NaN         NaN       NaN
# cep           0.019268  0.019268  0.019268    0.083333  0.000000
# dsct          0.186732  0.186732  0.186732    0.800000  0.416667
# ecl           0.954338  0.954338  0.954338    0.994898  0.263158
# lpv           0.207071  0.207071  0.207071    0.518519  0.037037
# rrlyr         0.038710  0.038710  0.038710    0.333333  0.000000
#
#            B2_cut_label  B2_cut_split  predict_B2_cut  B2_cut_probability  \
# ogle_type
# ELL            1.000000      0.967742        0.967742            0.967742
# Mira                NaN           NaN             NaN                 NaN
# cep            0.090909      0.019268        0.019268            0.019268
# dsct           1.000000      0.186732        0.186732            0.186732
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=ogle_test, x='multiplicity_probability', hue='ogle_type', common_norm=False, fill=False)
plt.title("Distribución de 'multiplicity_probability' por 'ogle_type'")
plt.show()

# %%
df['vsx_split']
# Out:
# 0          no_used
# 1          no_used
# 2          no_used
# 3          no_used
# 4          no_used
#             ...
# 1089913       test
# 1089914      train
# 1089915      train
# 1089916      train
# 1089917       test
# Name: vsx_split, Length: 1089918, dtype: object
